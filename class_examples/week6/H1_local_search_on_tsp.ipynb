# %% [markdown]
# # Local Search for the TSP
#
# Consider the classical Traveling Salesman Problem (TSP, see the Classical Problems Library). The class provided below represents the TSP. Objects of this class represent instances of the TSP.
#
# The data of the instances is provided in the files contained in the `tsp_instances` folder. For each instance we are given the data of the problem (files `*.tsp`) and the optimal solution, if exists (files`*.opt.tour`). The package `tsplib95` reads such files and makes its data available in a suitable Python object. The package is described here https://pypi.org/project/tsplib95/.
#
# The data of the instances is taken from a set of known benchmark instances (known as the TSPLIB 95 library)
# which are made available at this link http://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/.
# In the TSPLIB there are several instances of various sizes. For several instances the library provides also the
# optimal solution, if it is known (some instances are so difficult that the optimal solution has not yet been found). In our example we will use a small instance for which we know the optimal solution.
#
# - Q1. Find solutions to the given instance of the TSP using a local search algorithm
# - Q2. Compare the solution you obtain to the optimal solution (the optimal solution and its cost are given by the class below).

# %%
# %pip install wrapt
import tsplib95


class TSP:

    def __init__(self,instance_name:str, optimal_tour:str):
        '''
        Generates the data of the instance given the name of the file
        containing the data of the instance and the name of the file containing the optimal solution.
        '''
        self.data = tsplib95.load('tsp_instances/'+ instance_name)
        self.optimal_tour = tsplib95.load('tsp_instances/' + optimal_tour)

    def get_nodes(self):
        '''
        Returns the list of nodes.
        '''
        return list(self.data.get_nodes())

    def get_n_nodes(self):
        return len(self.get_nodes())

    def get_distances(self):
        '''
        Returns the distances matrix.
        '''
        return self.data.edge_weights

    def get_distance(self,i:int,j:int):
        '''
        Returns the distance between given nodes i and j.
        '''
        return self.data.get_weight(i,j)

    def get_node_coordinates(self,i:int):
        '''
        Returns the coordinates of the nodes.
        '''
        print(self.data.node_coords)

    def get_n_optimal_tours(self):
        '''
        Returns the list of optimal tours (there may be more than one, though often only one).
        '''
        return len(self.optimal_tour.tours)

    def get_optimal_tour(self,n_tour=0):
        '''
        Returns a specific optimal tour (with no arguments returns the first).
        '''
        return self.optimal_tour.tours[n_tour]

    def get_optimal_tour_length(self,n_tour=0):
        '''
        Returns the length (objective value) of an optimal tour (default the first tour).
        '''
        return self.get_tour_length(self.optimal_tour.tours[n_tour])

    def get_tour_length(self, tour:list):
        '''
        Calculates the length (objective value) of a tour we pass as an argument.
        Note that the tour is first added to a list since the method trace_tours accepts only lists of tours.
        '''
        tour_list = [tour]
        return self.data.trace_tours(tour_list)[0]
# Out:
# Requirement already satisfied: wrapt in /opt/conda/envs/python3/lib/python3.8/site-packages (1.14.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We create a small TSP instance

# %%
tsp = TSP("bays29.tsp","bays29.opt.tour")

# %%
tsp.get_optimal_tour()
# Out:
# [1,
#  28,
#  6,
#  12,
#  9,
#  5,
#  26,
#  29,
#  3,
#  2,
#  20,
#  10,
#  4,
#  15,
#  18,
#  17,
#  14,
#  22,
#  11,
#  19,
#  25,
#  7,
#  23,
#  27,
#  8,
#  24,
#  16,
#  13,
#  21]

# %%
tsp.get_optimal_tour_length()
# Out:
# 2020

# %% [markdown]
# # Solution

# %% [markdown]
# We create a class that implements the LS algorithm

# %%
import copy
import random

class LocalSearch:

    def __init__(self,tsp:TSP):
        self.tsp = tsp

    def generate_inital_solution(self):
        '''
        Does the following:
        (i) Gets the list of nodes of the tsp problem
        (ii) Makes a deep copy of the list of nodes.
        This ensures that by changing the order in the initial solution we
        do not modify the list of nodes in the tsp class.
        (iii) performs a random permutation of the nodes
        '''
        # Gets the nodes
        nodes = self.tsp.get_nodes()
        # Makes a deep copy
        initial_solution = copy.deepcopy(nodes)
        # Shuffles them
        random.shuffle(initial_solution)
        return initial_solution



    def swap(self,solution:list, i:int, j:int):
        '''
        Swaps the elements in position i and j in the given solution.
        Dows the following:
        (i) Makes a deep copy of the solution, so that we return a different list
        (ii) Keeps track of the elements in position i and j
        (iii) Swaps them
        '''
        new_solution = copy.deepcopy(solution)
        element_i = new_solution[i]
        element_j = new_solution[j]
        new_solution[i] = element_j
        new_solution[j] = element_i
        return new_solution



    def find_first_improving_solution(self,solution:list):
        current_solution = copy.deepcopy(solution)
        cost_current_solution = self.tsp.get_tour_length(current_solution)
        print("Cost current solution ", cost_current_solution)
        found_improving_solution = False
        for (i, j) in [(a, b) for a in range(len(current_solution)) for b in range(len(current_solution)) if a > b]:
            new_solution = self.swap(current_solution, i, j)
            cost_new_solution = self.tsp.get_tour_length(new_solution)

            if cost_new_solution < cost_current_solution:
                print("Found improving solution with cost", cost_new_solution)
                current_solution = new_solution
                found_improving_solution = True
                # When the first improving solution is found it breaks the loop
                # so that it stops looking for new solutions
                break
        return found_improving_solution, current_solution



    def solve_with_first_improvement(self,initial_solution:list):
        current_solution = copy.deepcopy(initial_solution)
        improving_solution = True
        iteration = 0;
        while improving_solution and (iteration < 500):
            print("Iteration ",iteration)
            improving_solution = False
            iteration += 1
            found_improving_solution, new_solution = self.find_first_improving_solution(current_solution)
            if found_improving_solution:
                improving_solution = found_improving_solution
                current_solution = new_solution
            else:
                print("No improving solution found")
        return current_solution

# %% [markdown]
# We create create a local search object

# %%
ls = LocalSearch(tsp=tsp)

# %% [markdown]
# We create an initial solution

# %%
initial_solution = ls.generate_inital_solution()
print(initial_solution)
print("Cost initial solution", tsp.get_tour_length(initial_solution))
# Out:
# [1, 13, 27, 11, 4, 28, 12, 14, 3, 21, 25, 18, 8, 23, 10, 16, 9, 6, 2, 20, 17, 19, 26, 24, 29, 7, 15, 5, 22]
# Cost initial solution 6267

# %% [markdown]
# We find a local optimum

# %%
local_optimum = ls.solve_with_first_improvement(initial_solution)
# Out:
# Iteration  0
# Cost current solution  6267
# Found improving solution with cost 6160
# Iteration  1
# Cost current solution  6160
# Found improving solution with cost 6053
# Iteration  2
# Cost current solution  6053
# Found improving solution with cost 5995
# Iteration  3
# Cost current solution  5995
# Found improving solution with cost 5899
# Iteration  4
# Cost current solution  5899
# Found improving solution with cost 5792
# Iteration  5
# Cost current solution  5792
# Found improving solution with cost 5704
# Iteration  6
# Cost current solution  5704
# Found improving solution with cost 5686
# Iteration  7
# Cost current solution  5686
# Found improving solution with cost 5617
# Iteration  8
# Cost current solution  5617
# Found improving solution with cost 5448
# Iteration  9
# Cost current solution  5448
# Found improving solution with cost 5441
# Iteration  10
# Cost current solution  5441
# Found improving solution with cost 5321
# Iteration  11
# Cost current solution  5321
# Found improving solution with cost 5311
# Iteration  12
# Cost current solution  5311
# Found improving solution with cost 5309
# Iteration  13
# Cost current solution  5309
# Found improving solution with cost 5249
# Iteration  14
# Cost current solution  5249
# Found improving solution with cost 5243
# Iteration  15
# Cost current solution  5243
# Found improving solution with cost 5092
# Iteration  16
# Cost current solution  5092
# Found improving solution with cost 5062
# Iteration  17
# Cost current solution  5062
# Found improving solution with cost 5024
# Iteration  18
# Cost current solution  5024
# Found improving solution with cost 4980
# Iteration  19
# Cost current solution  4980
# Found improving solution with cost 4970
# Iteration  20
# Cost current solution  4970
# Found improving solution with cost 4964
# Iteration  21
# Cost current solution  4964
# Found improving solution with cost 4949
# Iteration  22
# Cost current solution  4949
# Found improving solution with cost 4896
# Iteration  23
# Cost current solution  4896
# Found improving solution with cost 4778
# Iteration  24
# Cost current solution  4778
# Found improving solution with cost 4766
# Iteration  25
# Cost current solution  4766
# Found improving solution with cost 4762
# Iteration  26
# Cost current solution  4762
# Found improving solution with cost 4700
# Iteration  27
# Cost current solution  4700
# Found improving solution with cost 4694
# Iteration  28
# Cost current solution  4694
# Found improving solution with cost 4658
# Iteration  29
# Cost current solution  4658
# Found improving solution with cost 4610
# Iteration  30
# Cost current solution  4610
# Found improving solution with cost 4589
# Iteration  31
# Cost current solution  4589
# Found improving solution with cost 4569
# Iteration  32
# Cost current solution  4569
# Found improving solution with cost 4529
# Iteration  33
# Cost current solution  4529
# Found improving solution with cost 4528
# Iteration  34
# Cost current solution  4528
# Found improving solution with cost 4491
# Iteration  35
# Cost current solution  4491
# Found improving solution with cost 4407
# Iteration  36
# Cost current solution  4407
# Found improving solution with cost 4401
# Iteration  37
# Cost current solution  4401
# Found improving solution with cost 4358
# Iteration  38
# Cost current solution  4358
# Found improving solution with cost 4323
# Iteration  39
# Cost current solution  4323
# Found improving solution with cost 4288
# Iteration  40
# Cost current solution  4288
# Found improving solution with cost 4173
# Iteration  41
# Cost current solution  4173
# Found improving solution with cost 4117
# Iteration  42
# Cost current solution  4117
# Found improving solution with cost 4107
# Iteration  43
# Cost current solution  4107
# Found improving solution with cost 4102
# Iteration  44
# Cost current solution  4102
# Found improving solution with cost 4046
# Iteration  45
# Cost current solution  4046
# Found improving solution with cost 4039
# Iteration  46
# Cost current solution  4039
# Found improving solution with cost 4000
# Iteration  47
# Cost current solution  4000
# Found improving solution with cost 3988
# Iteration  48
# Cost current solution  3988
# Found improving solution with cost 3894
# Iteration  49
# Cost current solution  3894
# Found improving solution with cost 3870
# Iteration  50
# Cost current solution  3870
# Found improving solution with cost 3849
# Iteration  51
# Cost current solution  3849
# Found improving solution with cost 3747
# Iteration  52
# Cost current solution  3747
# Found improving solution with cost 3696
# Iteration  53
# Cost current solution  3696
# Found improving solution with cost 3656
# Iteration  54
# Cost current solution  3656
# Found improving solution with cost 3516
# Iteration  55
# Cost current solution  3516
# Found improving solution with cost 3482
# Iteration  56
# Cost current solution  3482
# Found improving solution with cost 3424
# Iteration  57
# Cost current solution  3424
# Found improving solution with cost 3396
# Iteration  58
# Cost current solution  3396
# Found improving solution with cost 3374
# Iteration  59
# Cost current solution  3374
# Found improving solution with cost 3243
# Iteration  60
# Cost current solution  3243
# Found improving solution with cost 3235
# Iteration  61
# Cost current solution  3235
# Found improving solution with cost 3230
# Iteration  62
# Cost current solution  3230
# Found improving solution with cost 3112
# Iteration  63
# Cost current solution  3112
# Found improving solution with cost 3072
# Iteration  64
# Cost current solution  3072
# Found improving solution with cost 3041
# Iteration  65
# Cost current solution  3041
# Found improving solution with cost 3040
# Iteration  66
# Cost current solution  3040
# Found improving solution with cost 3017
# Iteration  67
# Cost current solution  3017
# Found improving solution with cost 2979
# Iteration  68
# Cost current solution  2979
# Found improving solution with cost 2974
# Iteration  69
# Cost current solution  2974
# Found improving solution with cost 2962
# Iteration  70
# Cost current solution  2962
# Found improving solution with cost 2942
# Iteration  71
# Cost current solution  2942
# Found improving solution with cost 2889
# Iteration  72
# Cost current solution  2889
# Found improving solution with cost 2770
# Iteration  73
# Cost current solution  2770
# Found improving solution with cost 2729
# Iteration  74
# Cost current solution  2729
# Found improving solution with cost 2670
# Iteration  75
# Cost current solution  2670
# Found improving solution with cost 2651
# Iteration  76
# Cost current solution  2651
# Found improving solution with cost 2642
# Iteration  77
# Cost current solution  2642
# Found improving solution with cost 2591
# Iteration  78
# Cost current solution  2591
# Found improving solution with cost 2576
# Iteration  79
# Cost current solution  2576
# Found improving solution with cost 2540
# Iteration  80
# Cost current solution  2540
# Found improving solution with cost 2535
# Iteration  81
# Cost current solution  2535
# Found improving solution with cost 2502
# Iteration  82
# Cost current solution  2502
# Found improving solution with cost 2479
# Iteration  83
# Cost current solution  2479
# Found improving solution with cost 2432
# Iteration  84
# Cost current solution  2432
# No improving solution found

# %% [markdown]
# We compare its cost with the optimal cost

# %%
print(local_optimum)
print("Cost local optimum",tsp.get_tour_length(local_optimum))
print(tsp.get_optimal_tour())
print(tsp.get_optimal_tour_length())
# Out:
# [17, 14, 16, 24, 27, 23, 8, 1, 28, 5, 3, 29, 26, 9, 12, 6, 21, 2, 20, 18, 15, 4, 10, 13, 19, 7, 25, 11, 22]
# Cost local optimum 2432
# [1, 28, 6, 12, 9, 5, 26, 29, 3, 2, 20, 10, 4, 15, 18, 17, 14, 22, 11, 19, 25, 7, 23, 27, 8, 24, 16, 13, 21]
# 2020
